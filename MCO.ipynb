# %% [markdown]
# <a href="https://colab.research.google.com/github/carlossuazo/CourseraAngular/blob/master/MCO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Descomprimimos los archivos necesarios para aplicar el XGBoost

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# Esto ya se encuentra descomprimido en nuestro drive
#!tar -xvf "/content/gdrive/MyDrive/MCO/data/INRIAPerson.tar" -C "/content/gdrive/MyDrive/MCO/data/"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import cv2
import glob

ROOT_PATH  = '/content/gdrive/MyDrive/MCO/data/INRIAPerson'
TRAIN_PATH = '/Train/pos/'

ext = ['png', 'jpg', 'gif']    # Add image formats here

files = []
[files.extend(glob.glob(ROOT_PATH + TRAIN_PATH + '*.' + e)) for e in ext]

images = [cv2.imread(file) for file in files]

# %%
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from PIL import Image


images = [cv2.imread(file) for file in files]

gray = cv2.cvtColor(images[0], cv2.COLOR_BGR2GRAY)
# cv2_imshow(gray)

# %%
gray
# Out:
# array([[160, 148, 135, ..., 162, 155, 151],
#        [148, 144, 146, ..., 161, 153, 151],
#        [141, 143, 160, ..., 153, 150, 149],
#        ...,
#        [ 68,  81,  83, ..., 126, 131, 123],
#        [ 66,  84,  90, ..., 145, 150, 140],
#        [ 85,  89,  92, ..., 150, 157, 158]], dtype=uint8)

# %%
from skimage.feature import hog
# resized_img = train_bgi[:,:,1]

for i in range(0,1):
  fd, hog_image = hog(images[0], orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, multichannel=True)
  plt.imshow(hog_image)
  plt.show()

# %%
################################################################################
# CARLOS #
################################################################################
print("Hola.")
# !echo "# XGBoost_GA" >> README.md
# !git config --global user.email "carlos91suazo@gmail.com"
# !git config --global user.name "Your Name"

# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/carlossuazo/XGBoost_GA.git
# !git push -u origin main
# Out:
# Hola.
# Reinitialized existing Git repository in /content/.git/
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@648250b568eb.(none)')
# error: refname refs/heads/master not found
# fatal: Branch rename failed
# error: src refspec main does not match any.
# error: failed to push some refs to 'https://github.com/carlossuazo/XGBoost_GA.git'
